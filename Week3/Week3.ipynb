# %% [markdown]
# <a href="https://colab.research.google.com/github/gitBarrettJones/CIS115-Spring2026-Assignments/blob/main/Week3/Week3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Assign values to name, goal, birth_year and current year
#Calculate age
#Print top border with string multiplication
#Print bio sentences
#Print bottom border with string multiplication
