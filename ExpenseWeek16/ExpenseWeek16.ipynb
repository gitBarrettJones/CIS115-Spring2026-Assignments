# %% [markdown]
# <a href="https://colab.research.google.com/github/gitBarrettJones/CIS115-Spring2026-Assignments/blob/main/ExpenseWeek16/ExpenseWeek16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)


# FUNCTION DEFINITIONS
## create a list to store records ##

expenses = []


## def the expense to be added ##
# print a message for user to add expense #
while True:
  print("--Add Expense--")
# ask the user to input a Category #
  category = input("Enter a Category (or input 'done' to finish): ")
  if category.lower() == "done":
    break
# ask the user to input a Vendor #
  vendor = input("Enter a Vendor: ")
# ask the user to input a amount (use float) #
  amount = float(input("Enter an Amount: "))
# ensure user is only able to input a number for amount (loop) #
# ask the user to input a date mm-dd-yyyy #
  date = input("Enter a Date (mm-dd-yyyy): ")
# print the user a message after adding the expense #
## create dictionary for storage of expenses ##
  expense = {
    "Category": category,
    "Vendor": vendor,
    "Amount": amount,
    "Date": date
  }
  expenses.append(expense)
  print("Expense added successfully!")

print("Stored Expenses:")
print(expenses)
## def total expenses ##
# set the beginning total to = 0 #
# for expense within expenses add to total amount #
# print the user a message with total calculation #

## def total category ##
# ask the user to input a category to see #
# for any matching category display the total amount within #

## def total vendor ##
# ask the user to input a vendor #
# for any matching vendor display the total amount within #

## def the menu to select options ##
# display menu option #
# add expense, view total all, view total by category, view total by vendor, exit #


# PROGRAM LOGIC

## loop program ##

## call the menu ##
# ask the user to input an option #
# for the selected option picked call the corresponding function #
# Out:
# --Add Expense--
# Enter a Category (or input 'done' to finish): Food
# Enter a Vendor: Wayback Burger
# Enter an Amount: 15.50
# Enter a Date (mm-dd-yyyy): 05-04-2026
# Expense added successfully!
# --Add Expense--
# Enter a Category (or input 'done' to finish): Shopping
# Enter a Vendor: Target
# Enter an Amount: 28.90
# Enter a Date (mm-dd-yyyy): 05/01/2026
# Expense added successfully!
# --Add Expense--
# Enter a Category (or input 'done' to finish): Food
# Enter a Vendor: Scooter's coffee
# Enter an Amount: 8.31
# Enter a Date (mm-dd-yyyy): 04-15-2026
# Expense added successfully!
# --Add Expense--
# Enter a Category (or input 'done' to finish): done
# Stored Expenses:
# [{'Category': 'Food', 'Vendor': 'Wayback Burger', 'Amount': 15.5, 'Date': '05-04-2026'}, {'Category': 'Shopping', 'Vendor': 'Target', 'Amount': 28.9, 'Date': '05/01/2026'}, {'Category': 'Food', 'Vendor': "Scooter's coffee", 'Amount': 8.31, 'Date': '04-15-2026'}]
