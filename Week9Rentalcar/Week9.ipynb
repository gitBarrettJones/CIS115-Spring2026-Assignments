# %% [markdown]
# <a href="https://colab.research.google.com/github/gitBarrettJones/CIS115-Spring2026-Assignments/blob/main/Week9Rentalcar/Week9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: rentalcar.py
# IMPORT STATEMENTS

# FUNCTION DEFINITIONS #

## Create Car Classifications ##
# B = Budget = $40 daily #
# S = Standard = $60 daily #
# L = Luxary = $ 80 daily #

## Daily car usage ##
# Days #
# Price #

## Create Odometer for mileage ##
# Starting_mileage #
# Used_mileage #

# PROGRAM LOGIC #

## Ensure the user Inputs the one of the three Car Classifications##
# print Car Classifications and price for user to input #
# gather user car input data #
# gather the days the car will be used #
# if statment for Car with price #
# else return a error message with solution #
# Add the price of the car and days selected #
#print a message with selected car and price #

## Mileage input and display prices ##
# print a message explaining using below 100 miles is free #
# print a message explaining any miles above 100 will be an addition charge #
# Gather mileage data from user input #
# Compare Starting_mileage to Used_mileage #
# if > 100 = 0 #
# else + fee of .35 per mile #

## Fruitful Function that returns total bill ##
# Add Price and Use_mileage #
# Return as the Total_Bill #
