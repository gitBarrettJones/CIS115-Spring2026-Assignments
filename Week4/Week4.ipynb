# %% [markdown]
# <a href="https://colab.research.google.com/github/gitBarrettJones/CIS115-Spring2026-Assignments/blob/main/Week4/Week4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS
# 1. Define print_bio with three parameters: name, age, and goal.
def print_bio(name, age, goal):
    border = "*" * 20

    print(border)
    print("Name:", name, "Age:", age, "Goal:", goal)
    print(border)
    print() #blank line


# 2. Inside the function, use string multiplication (*) for a border line.
# PROGRAM EXECUTION
# 3. Print the bio details using the parameter names.

# PROGRAM LOGIC
# 1. Call print_bio using my own info.
# 2. Call print_bio using [Name of Famous Person].
# 3. Call print_bio using [Name of Fictional Character].

print_bio("Barrett,", 26,"Finish college.")

print_bio("Bill Gates,", 19,"Have computers within every household.")

print_bio("Bruce Wayne,", 30,"Stop crime in Gotham City.")
# Out:
# ********************
# Name: Barrett, Age: 26 Goal: Finish college.
# ********************
#
# ********************
# Name: Bill Gates, Age: 19 Goal: Have computers within every household.
# ********************
#
# ********************
# Name: Bruce Wayne, Age: 30 Goal: Stop crime in Gotham City.
# ********************
