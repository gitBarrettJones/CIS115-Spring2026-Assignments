# %% [markdown]
# <a href="https://colab.research.google.com/github/gitBarrettJones/CIS115-Spring2026-Assignments/blob/main/Week12rectangle/Week12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: rectangle.py
# IMPORT STATEMENTS

# FUNCTION DEFINITIONS
## define calculate_rectangle parameters length & width ##
def calculate_rectangle(length, width):
# find area using formula length * width #
    area = length * width
# find perimeter using formula 2(length + width) #
    perimeter = 2 * (length + width)
# return area and perimeter #
    return (area, perimeter)

# PROGRAM LOGIC
## User input ##
# ask user for length and width using float()#
length = float(input("What is the length: "))
width = float(input("What is the width: "))
## call the calculate_rectangle function ##
result = calculate_rectangle(length, width)
# unpack the tuple as two variable my_area, my_perimeter #
my_area, my_perimeter = result
## print the results ##
print("--Results--")
print("The Area of the rectangle is:", my_area)
print("The Perimeter of the rectangle is:", my_perimeter)
# Out:
# What is the length: 5
# What is the width: 10
# --Results--
# The Area of the rectangle is: 50.0
# The Perimeter of the rectangle is: 30.0
