# %% [markdown]
# <a href="https://colab.research.google.com/github/gitBarrettJones/CIS115-Spring2026-Assignments/blob/main/WeekFinal/AI2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3
from datetime import datetime, timedelta

# Connect to database
conn = sqlite3.connect("garden.db")
cursor = conn.cursor()

# Create table
cursor.execute("""
CREATE TABLE IF NOT EXISTS plants (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    name TEXT,
    type TEXT,
    last_watered TEXT,
    frequency INTEGER
)
""")
conn.commit()


def add_plant():
    name = input("Plant name: ")
    plant_type = input("Plant type: ")
    last_watered = input("Last watered (YYYY-MM-DD): ")
    frequency = int(input("Watering frequency (days): "))

    cursor.execute("""
    INSERT INTO plants (name, type, last_watered, frequency)
    VALUES (?, ?, ?, ?)
    """, (name, plant_type, last_watered, frequency))

    conn.commit()
    print("Plant added!\n")


def view_plants():
    cursor.execute("SELECT * FROM plants")
    plants = cursor.fetchall()

    today = datetime.today()

    for plant in plants:
        plant_id, name, plant_type, last_watered, frequency = plant

        last_date = datetime.strptime(last_watered, "%Y-%m-%d")
        next_water = last_date + timedelta(days=frequency)

        days_left = (next_water - today).days

        status = "✅ OK"
        if days_left < 0:
            status = "💧 Needs Water!"

        print(f"""
ID: {plant_id}
Name: {name}
Type: {plant_type}
Next Watering: {next_water.date()}
Days Left: {days_left}
Status: {status}
------------------------
""")


def main():
    while True:
        print("""
1. Add Plant
2. View Plants
3. Exit
""")

        choice = input("Choose an option: ")

        if choice == "1":
            add_plant()
        elif choice == "2":
            view_plants()
        elif choice == "3":
            break
        else:
            print("Invalid choice.\n")


if __name__ == "__main__":
    main()
    conn.close()
# Out:
# 1. Add Plant
# 2. View Plants
# 3. Exit
