# %% [markdown]
# <a href="https://colab.research.google.com/github/gitBarrettJones/CIS115-Spring2026-Assignments/blob/main/Week5/Week5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)


# FUNCTION DEFINITIONS
# 1. Define calculate_ticket(age, hour)

def calculate_ticket(age, hour):

    # 2. Logic: If age <= 12 or age >= 65, price = 8. Otherwise, price = 12.

    if age <= 12 or age >= 65:
        price = 8.00
    else:
        price = 12.00

    # 3. Logic: If hour < 17, subtract 2 from the price.

    if hour < 17:
        price -= 2.00


    # 4. Return the final price.
    # 4. Print the final price.




# PROGRAM LOGIC
# 1. input() for age (int)
    print(f"The price of your ticket is ${price:.2f}.")


# PROGRAM LOGIC
age = int(input("Enter age: "))
hour = int(input("Enter movie hour (0-23, 24-hour format): "))
calculate_ticket(age, hour)
# Out:
# Enter age: 12
# Enter movie hour (0-23, 24-hour format): 16
# The price of your ticket is $6.00.
